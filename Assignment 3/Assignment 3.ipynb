# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
dataset1 = pd.read_csv('Assignment3.1.csv')

# %%
dataset2 = pd.read_csv('Assignment3.2.csv')

# %%
ds=pd.merge(dataset1,dataset2)

# %%
dataset1
# Out:
#        Region                     District                   FacilityName  \
# 0     Ashanti                Offinso North              A.M.E Zion Clinic
# 1     Ashanti             Bekwai Municipal              Abenkyiman Clinic
# 2     Ashanti                 Adansi North           Aboabo Health Centre
# 3     Ashanti                Afigya-Kwabre        Aboabogya Health Centre
# 4     Ashanti                       Kwabre           Aboaso Health Centre
# 5     Ashanti                Offinso North         Aboffour Health Centre
# 6     Ashanti             Atwima-Nwabiagya         Abuakwa Maternity Home
# 7     Ashanti              Atwima-Kwanwoma       Aburaso Methodist clinic
# 8     Ashanti       Ejisu-Juaben Municipal          Achiase Health Centre
# 9     Ashanti            Mampong Municipal          Adidwan Health Centre
# 10    Ashanti                 Amansie West                  Adimposo CHPS
# 11    Ashanti  Asante-Akim North Municipal                  Adom Hospital
# ...

# %%
dataset2
# Out:
#        Region                               Facility  Tier  Latitude
# 0     Ashanti                PEACE AND LOVE HOSPITAL   2.0   7.40801
# 1     Ashanti                         TODAH HOSPITAL   2.0   7.40801
# 2     Ashanti              ASOKWA CHILREN'S HOSPITAL   2.0   7.40801
# 3     Ashanti                   FANKYEBEBRA HOSPITAL   2.0   7.40801
# 4     Ashanti                       MICHMIT HOSPITAL   2.0   7.40801
# 5     Ashanti                          SABS HOSPITAL   2.0   7.40801
# 6     Ashanti            SARFO ADU MEMORIAL HOSPITAL   2.0   7.40801
# 7     Ashanti                          CITY HOSPITAL   2.0   7.40801
# 8     Ashanti            AYUSH MEMORIAL HOSPITAL LTD   2.0   7.40801
# 9     Ashanti                   ROYAL PLACE HOSPITAL   2.0   7.40801
# 10    Ashanti                   ASAFO AGYEI HOSPITAL   2.0   7.40801
# 11    Ashanti        FIRST ROYAL SPECIALIST HOSPITAL   2.0   7.40801
# 12    Ashanti                   GARDEN CITY HOSPITAL   2.0   7.40801
# ...

# %%
ds
# Out:
#       Region       District       FacilityName    Type      Town Ownership  \
# 0    Ashanti  Offinso North  A.M.E Zion Clinic  Clinic  Afrancho      CHAG
# 1    Ashanti  Offinso North  A.M.E Zion Clinic  Clinic  Afrancho      CHAG
# 2    Ashanti  Offinso North  A.M.E Zion Clinic  Clinic  Afrancho      CHAG
# 3    Ashanti  Offinso North  A.M.E Zion Clinic  Clinic  Afrancho      CHAG
# 4    Ashanti  Offinso North  A.M.E Zion Clinic  Clinic  Afrancho      CHAG
# 5    Ashanti  Offinso North  A.M.E Zion Clinic  Clinic  Afrancho      CHAG
# 6    Ashanti  Offinso North  A.M.E Zion Clinic  Clinic  Afrancho      CHAG
# 7    Ashanti  Offinso North  A.M.E Zion Clinic  Clinic  Afrancho      CHAG
# 8    Ashanti  Offinso North  A.M.E Zion Clinic  Clinic  Afrancho      CHAG
# 9    Ashanti  Offinso North  A.M.E Zion Clinic  Clinic  Afrancho      CHAG
# 10   Ashanti  Offinso North  A.M.E Zion Clinic  Clinic  Afrancho      CHAG
# ...
